# %%
from utils import *
from preprocessing import *
from neural_networks import *
from embeddings import *
# Out:
# C:\Users\Sarah\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
MAXLEN = 40
NUM_WORD = 120000

# %%
train_set, unknown = train_test_cleaner()

# %%
train_set
# Out:
#                                                    tweet  label
# 0      user i dunno justin read my mention or not mul...      1
# 1      because your logic is so dumb kiss i will not ...      1
# 2      user just put casper in a box exclamationMark ...      1
# 3      user user thanks sir do not trip lil mama mult...      1
# 4      visiting my brother tmr is the bestest birthda...      1
# 5      user yay exclamationMark hashtag lifecompleted...      1
# 6      user hashtag dnextalbumtitle feel for you roll...      1
# 7      workin hard or hardly workin rt user at hardee...      1
# 8      user i saw multistop i ll be replying in a bit...      1
# 9                                  this is were i belong      1
# 10     user anddd to cheer hashtag national questionMark      1
# 11     we send an invitation to shop on line exclamat...      1
# 12                  just woke up kiss finna go to church      1
# 13         user agreed exclamationMark more day left tho      1
# ...

# %%
train_set.sample(frac=1, random_state=1).reset_index(drop=True)
# Out:
#                                                     tweet  label
# 0       user cheer exclamationMark you too kiss good l...      1
# 1       the seven paperback chosen for their unique dn...      0
# 2       wow multistop you freaking lied to me multisto...      0
# 3       nephrology and urology contemporary issue in s...      0
# 4       hashtag thoughtsduringschool i dont wanna go t...      0
# 5       user whhhaaa exclamationMark flish we forgot t...      1
# 6       cher fan kiss follow user i follow and like ki...      1
# 7                  user i know it made my day x and worse      0
# 8        in the year multistop really miss them a lot url      0
# 9              user yay now you can go to sleep multistop      1
# 10      user user user user awww niall and zayn s litt...      1
# 11           the a c make it so hard to get out of my bed      0
# 12      the lady collapsed and sadly died le than a mi...      0
# ...

# %%
create_and_save_embedding_vect(train_set)

# %%
X_train, X_test, y_train, y_test = train_test_split(train_set['tweet'], train_set['label'], test_size=0.05, random_state=42)

# %%
#shuffle the dataset to mix the labels
#X_train = X_train.sample(frac=1, random_state=1).reset_index(drop=True)

# %%
X_train,X_test, vocab_size, tokenizer = tok_and_pad_for_nn(X_train, X_test, MAXLEN, NUM_WORD)

# %%
embedding_matrix = create_embedding_matrix(vocab_size, tokenizer)

# %%
simple_nn = simple_nn(X_train, y_train,X_test,y_test,vocab_size,embedding_matrix, MAXLEN)

# %%
type(y_test.values)

# %%
unknown

# %%
preds_simple_nn = compute_predictions_nn(to_predict = unknown, threshold = 0.5, model = simple_nn, tokenizer = tokenizer,maxlen=MAXLEN)

# %%
create_csv_submission(preds_simple_nn, "./ensemble/pred1.csv")

# %%
a

# %%
train_set = train_set.sample(frac=1, random_state=1).reset_index(drop=True)
