# %%
from utils import *
from preprocessing import *
from neural_networks import *
from embeddings import *
# Out:
# C:\Users\Sarah\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
MAXLEN = 40
NUM_WORD = 120000

# %%
train_set, unknown = train_test_cleaner()

# %%
unknown
# Out:
#                                                    tweet
# 1      sea doo pro sea scooter sport with the portabl...
# 2      user shuck well i work all week so now i can n...
# 3                i cant stay away from bug thats my baby
# 4      user no ma am exclamationMark haha im perfectl...
# 5      whenever i fall asleep watching the tv kiss i ...
# 6      user he need to get rid of that thing exclamat...
# 7               it whatever multistop in a terrible mood
# 8      yes exclamationMark rt user user thanks jordan...
# 9      my friend user text me to check up on me last ...
# 10     user hashtag followback please multistop when ...
# 11     watch some of y all dumb ass get lock up today...
# 12     obsessed with hashtag phasell user you killed ...
# 13     user robert de niro is not gay multistop but w...
# 14     user canada have to do it in grade multistop b...
# 15     user please say hi to denmark exclamationMark ...
# 16                                   finally am home now
# 17     x custom picture frame poster frame multistop ...
# 18     s o to my new follower multistop mention me fo...
# 19     user yep kiss look like the best team will sta...
# 20     nhl s bettman suspension criticism gamesmanshi...
# 21     user no way i m pro andd user haha she is rubb...
# 22     barrel pickle multistop pound these german pic...
# 23     i completed a whole cup of tea today at jessic...
# 24     expo precision point whiteboard eraser happy k...
# 25     hashtag yougetmajorpointsif you play soccer mu...
# 26     task essential harness leather scribe keeper s...
# 27     user hashtag needtoreesthisshit hashtag should...
# 28     user haha ok kiss i ll come over kiss ton of b...
# 29     laurie s garden design protective decal skin s...
# 30                 user no way he s mine exclamationMark
# ...                                                  ...
# 9971   it s clear that these new goth are learning to...
# 9972   it s clear that these new goth are learning to...
# 9973   another day at home sick kiss can this be over...
# 9974   user of your own wee golden nugget there simme...
# 9975   user all disney movie are classic film they wi...
# 9976   x custom picture frame poster frame multistop ...
# 9977   x custom picture frame poster frame multistop ...
# 9978                         user glad it arrived safely
# 9979   im not gonna care if ur not going to either i ...
# 9980   monk season four dvd return to the scene of th...
# 9981   i want to wish my beautiful cousin user a happ...
# 9982   rt user the first rule of sex is kiss there is...
# 9983   stay a u are darla happy rt user i know haha u...
# 9984   user user most embarrassing thing thats ever h...
# 9985   i wonder if user will ever hashtag followback ...
# 9986   i wonder if user will ever hashtag followback ...
# 9987   anaheim duck cake cupcake topper pack a qualit...
# 9988   shoutout to user go follow her guy exclamation...
# 9989   user multistop good morning brother kiss multi...
# 9990   you re welcome mr multistop bruce kiss tell hi...
# 9991          user follow me back please exclamationMark
# 9992   user omg exclamationMark i screamed at the end...
# 9993   aww that s dissapointing that i can not make m...
# 9994                   user thankyouu po exclamationMark
# 9995   user i m afraid you re coming back to a lot of...
# 9996          had a nice time without my friend lastnite
# 9997   user no it s not exclamationMark please stop e...
# 9998   not without my daughter dvd two time oscar r w...
# 9999                  user have fun in class sweetcheeks
# 10000  making a r multistop e multistop a multistop l...
#
# [10000 rows x 1 columns]

# %%
create_and_save_embedding_vect(train_set)

# %%
X_train, X_test, y_train, y_test = train_test_split(train_set['tweet'], train_set['label'], test_size=0.05, random_state=42)

# %%
#shuffle the dataset to mix the labels
#X_train = X_train.sample(frac=1, random_state=1).reset_index(drop=True)

# %%
X_train,X_test, vocab_size, tokenizer = tok_and_pad_for_nn(X_train, X_test, MAXLEN, NUM_WORD)

# %%
embedding_matrix = create_embedding_matrix(vocab_size, tokenizer)

# %%
simple_nn = simple_nn(X_train, y_train,X_test,y_test,vocab_size,embedding_matrix, MAXLEN)
# Out:
# Train on 163641 samples, validate on 8613 samples
# Epoch 1/6
# 163641/163641 [==============================] - 5s 28us/step - loss: 0.5205 - acc: 0.7341 - val_loss: 0.4920 - val_acc: 0.7555
# Epoch 2/6
# 163641/163641 [==============================] - 4s 22us/step - loss: 0.4712 - acc: 0.7712 - val_loss: 0.4825 - val_acc: 0.7607
# Epoch 3/6
# 163641/163641 [==============================] - 4s 22us/step - loss: 0.4641 - acc: 0.7760 - val_loss: 0.4860 - val_acc: 0.7592
# Epoch 4/6
# 163641/163641 [==============================] - 4s 25us/step - loss: 0.4596 - acc: 0.7793 - val_loss: 0.4871 - val_acc: 0.7595
# Epoch 5/6
# 163641/163641 [==============================] - 4s 24us/step - loss: 0.4583 - acc: 0.7796 - val_loss: 0.4859 - val_acc: 0.7611
# Epoch 6/6
# 163641/163641 [==============================] - 3s 21us/step - loss: 0.4560 - acc: 0.7809 - val_loss: 0.4879 - val_acc: 0.7608
# 9067/9067 [==============================] - 0s 31us/step
# Test Score: 0.4885299732472887
# Test Accuracy: 0.7656336426734924

# %%
type(y_test.values)
# Out:
# numpy.ndarray

# %%
unknown
# Out:
#                                                    tweet
# 1      sea doo pro sea scooter sport with the portabl...
# 2      user shuck well i work all week so now i can n...
# 3                i cant stay away from bug thats my baby
# 4      user no ma am exclamationMark haha im perfectl...
# 5      whenever i fall asleep watching the tv kiss i ...
# 6      user he need to get rid of that thing exclamat...
# 7               it whatever multistop in a terrible mood
# 8      yes exclamationMark rt user user thanks jordan...
# 9      my friend user text me to check up on me last ...
# 10     user hashtag followback please multistop when ...
# 11     watch some of y all dumb ass get lock up today...
# 12     obsessed with hashtag phasell user you killed ...
# 13     user robert de niro is not gay multistop but w...
# 14     user canada have to do it in grade multistop b...
# 15     user please say hi to denmark exclamationMark ...
# 16                                   finally am home now
# 17     x custom picture frame poster frame multistop ...
# 18     s o to my new follower multistop mention me fo...
# 19     user yep kiss look like the best team will sta...
# 20     nhl s bettman suspension criticism gamesmanshi...
# 21     user no way i m pro andd user haha she is rubb...
# 22     barrel pickle multistop pound these german pic...
# 23     i completed a whole cup of tea today at jessic...
# 24     expo precision point whiteboard eraser happy k...
# 25     hashtag yougetmajorpointsif you play soccer mu...
# 26     task essential harness leather scribe keeper s...
# 27     user hashtag needtoreesthisshit hashtag should...
# 28     user haha ok kiss i ll come over kiss ton of b...
# 29     laurie s garden design protective decal skin s...
# 30                 user no way he s mine exclamationMark
# ...                                                  ...
# 9971   it s clear that these new goth are learning to...
# 9972   it s clear that these new goth are learning to...
# 9973   another day at home sick kiss can this be over...
# 9974   user of your own wee golden nugget there simme...
# 9975   user all disney movie are classic film they wi...
# 9976   x custom picture frame poster frame multistop ...
# 9977   x custom picture frame poster frame multistop ...
# 9978                         user glad it arrived safely
# 9979   im not gonna care if ur not going to either i ...
# 9980   monk season four dvd return to the scene of th...
# 9981   i want to wish my beautiful cousin user a happ...
# 9982   rt user the first rule of sex is kiss there is...
# 9983   stay a u are darla happy rt user i know haha u...
# 9984   user user most embarrassing thing thats ever h...
# 9985   i wonder if user will ever hashtag followback ...
# 9986   i wonder if user will ever hashtag followback ...
# 9987   anaheim duck cake cupcake topper pack a qualit...
# 9988   shoutout to user go follow her guy exclamation...
# 9989   user multistop good morning brother kiss multi...
# 9990   you re welcome mr multistop bruce kiss tell hi...
# 9991          user follow me back please exclamationMark
# 9992   user omg exclamationMark i screamed at the end...
# 9993   aww that s dissapointing that i can not make m...
# 9994                   user thankyouu po exclamationMark
# 9995   user i m afraid you re coming back to a lot of...
# 9996          had a nice time without my friend lastnite
# 9997   user no it s not exclamationMark please stop e...
# 9998   not without my daughter dvd two time oscar r w...
# 9999                  user have fun in class sweetcheeks
# 10000  making a r multistop e multistop a multistop l...
#
# [10000 rows x 1 columns]

# %%
preds_simple_nn = compute_predictions_nn(to_predict = unknown, threshold = 0.5, model = simple_nn, tokenizer = tokenizer,maxlen=MAXLEN)

# %%
create_csv_submission(preds_simple_nn, "./ensemble/pred_simple_nn.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-14-75a5f148e30e> in <module>()
# ----> 1 create_csv_submission(preds_simple_nn, "./ensemble/pred_simple_nn.csv")
#
# ~\Documents\EPFL\4ème\text_classification\utils.py in create_csv_submission(y_pred, path)
#      11     """
#      12     ids=[i for i in range(1,len(y_pred)+1)]
# ---> 13     with open(path, 'w', newline='') as csvfile:
#      14         fieldnames = ['Id', 'Prediction']
#      15         writer = csv.DictWriter(csvfile, delimiter=",", fieldnames=fieldnames)
#
# FileNotFoundError: [Errno 2] No such file or directory: './ensemble/pred_simple_nn.csv'
